# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.parse import urljoin
import re
import json
import urllib.request


file_path = '/refrigerator project/recipe.json'
def toJson(recipe_dict):
    with open(file_path, 'w', encoding='utf-8') as file:
        json.dump(recipe_dict, file, ensure_ascii=False, indent='\t')


def url_func(n,m):
    url = 'https://www.10000recipe.com/profile/recipe.html?uid=gdubu33&page='
    url_list = []
    
    for num in range(n,m):
        req = urllib.request.Request(url + str(num))
        html = urllib.request.urlopen(url).read()
        soup = BeautifulSoup(html, 'html.parser')
        
        try:
            res = soup.find(class_='cont_list st3')
            for i in res.find_all('a'):
                url_tmp = i.get('href')
                url_list.append(url_tmp)
        except(AttributeError):
            pass
    return url_list
        
        
# url = 'https://www.10000recipe.com/recipe/6876875'
# response = requests.get(url)
# html = response.text

# soup = BeautifulSoup(html, 'html.parser')
num_id = 0
food_dicts = []
url_lists = url_func(1,2)

for url_str in url_lists:
    url = 'https://www.10000recipe.com'
    url = url + url_str
    response = requests.get(url)
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')

    #menu name
    res = soup.find('div', 'view2_summary')
    res = res.find('h3')
    menu_name = res.get_text().replace('\n',' ').replace('"','')

    #menu image
    res = soup.find('div', 'centeredcrop')
    res = res.find('img')
    menu_img = res.get('src')

    # ingredients
    res = soup.find('div','ready_ingre3')
    ingre_dict = {}
    ingre_list = []
    try:
        for n in res.find_all('ul'):
            for tmp in n.find_all('li'):
                ingredient_name = tmp.get_text().replace('\n','').replace(' ','')
                count = tmp.find('span')
                ingredient_tmp = count.get_text()
                ingredient_name = re.sub(ingredient_tmp, '',ingredient_name)
                ingredient_unit = ingredient_tmp.replace('/','').replace('+','')
                ingredient_unit = ''.join([i for i in ingredient_unit if not i.isdigit()])
                ingredient_count = re.sub(ingredient_unit, '', ingredient_tmp)

                ingre_dict = {"ingre_name": ingredient_name,
                             "ingre_count": ingredient_count,
                             "ingre_unit": ingredient_unit}

                ingre_list.append(ingre_dict)
    except(AttributeError):
        pass

    # recipe
    recipe_list = []
    res = soup.find('div','view_step')
    ind = 1
    for n in res.find_all('div', 'view_step_cont'):
        recipe_step_txt = n.get_text().replace('\n',' ')
        recipe_list.append(str(ind) + '. ' + recipe_step_txt)
        ind += 1

    food_dict = {"id":num_id,
                "name":menu_name,
                "img":menu_img,
                "ingre":ingre_list,
                 "url": url,
                "reci":recipe_list}
    num_id += 1
    food_dicts.append(food_dict)
    print(food_dict)

toJson(food_dicts)
# Out:
# {'id': 0, 'name': '서양식 계란찜! 오믈렛 대신 프리타타', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/11/03/6514dc211ace51210b156d2e077a37ff1.jpg', 'ingre': [{'ingre_name': '베이컨', 'ingre_count': '3', 'ingre_unit': '줄'}, {'ingre_name': '방울토마토', 'ingre_count': '5', 'ingre_unit': '개'}, {'ingre_name': '양파', 'ingre_count': '1/2', 'ingre_unit': '개'}, {'ingre_name': '시금치', 'ingre_count': '1', 'ingre_unit': '줌'}, {'ingre_name': '느타리버섯', 'ingre_count': '1', 'ingre_unit': '줌'}, {'ingre_name': '체다치즈', 'ingre_count': '1', 'ingre_unit': '장'}, {'ingre_name': '파마산치즈', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '달걀', 'ingre_count': '3', 'ingre_unit': '개'}, {'ingre_name': '우유', 'ingre_count': '200', 'ingre_unit': 'ml'}, {'ingre_name': '소금', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '후추', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '파슬리가루', 'ingre_count': '', 'ingre_unit': '약간'}], 'url': 'https://www.10000recipe.com/recipe/6945561', 'reci': ['1. 베이컨과 양파는 큼직하게 다지고, 방울토마토는 반 자르고, 느타리버섯과 시금치는 한 입 크기로 잘라요.', '2. 예열된 팬에 기름을 조금 두르고, 양파, 베이컨, 버섯, 시금치를 순서대로 볶아요.', '3. 볼에 달걀, 우유, 소금, 후추, 파마산치즈 가루를 섞어 달걀물을 만들어요.', '4. 달걀물에 볶아놓은 양파, 베이컨, 버섯, 시금치를 섞어요.', '5. 예열된 팬에 올리브유를 두르고, 달걀물을 부어 스크램블 하듯 익혀요.', '6. 달걀물이 몽글몽글 익기 시작하면 방울토마토와 체다치즈를 올려요.', '7. 바닥이 타지 않게 약불로 줄이고, 뚜껑을 닫아 속까지 익혀요.익으면 오븐에 넣어 윗면을 노릇하게 익혀도 좋아요.']}
# {'id': 1, 'name': '지금이 가장 맛있는 가을 무로 만든 칼칼한 돼지고기무조림 ', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/11/02/436eb8f4b8cb14b4446e12613cfcc9451.png', 'ingre': [{'ingre_name': '무', 'ingre_count': '300', 'ingre_unit': 'g'}, {'ingre_name': '대파', 'ingre_count': '1', 'ingre_unit': '대'}, {'ingre_name': '돼지고기', 'ingre_count': '300', 'ingre_unit': 'g'}, {'ingre_name': '물1+1/2종이컵', 'ingre_count': '1+1/2', 'ingre_unit': '종이컵'}, {'ingre_name': '맛술', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '소금', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '후추', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '고추장', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '고춧가루', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '올리고당', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '설탕', 'ingre_count': '1/2', 'ingre_unit': '숟가락'}, {'ingre_name': '다진마늘', 'ingre_count': '1/2', 'ingre_unit': '숟가락'}, {'ingre_name': '간장', 'ingre_count': '2', 'ingre_unit': '숟가락'}, {'ingre_name': '청양고추', 'ingre_count': '1/3', 'ingre_unit': '개'}, {'ingre_name': '홍고추', 'ingre_count': '1/3', 'ingre_unit': '개'}], 'url': 'https://www.10000recipe.com/recipe/6945543', 'reci': ['1. 무는 한 입 크기로 썰고 대파, 고추는 송송썬다.', '2. 돼지고기에 맛술, 소금, 후추를 뿌려 밑간한다.', '3. 볼에 양념 재료를 넣고 양념장을 만든다.', '4. 냄비에 물, 양념장, 무를 넣고 끓이다 무가 투명해지면 돼지고기 넣고 10분간 끓인다.물 대신 멸치다시마육수를 써도 좋아요.  \r                             키친아트 포르트 (FORT) 냄비                          ', '5. 대파, 고추를 넣고 한소끔 끓여 완성한다.']}
# {'id': 2, 'name': '오븐없이 비스킷을? 바질비스킷 with 큐원홈메이드 비스킷믹스', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/11/02/155e65b3383015a83619d3d3824385a01.jpg', 'ingre': [{'ingre_name': '큐원홈메이드비스킷믹스', 'ingre_count': '250', 'ingre_unit': 'g'}, {'ingre_name': '달걀', 'ingre_count': '1', 'ingre_unit': '개'}, {'ingre_name': '우유', 'ingre_count': '20', 'ingre_unit': 'ml'}, {'ingre_name': '바질페스토', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '레몬', 'ingre_count': '1', 'ingre_unit': '개'}], 'url': 'https://www.10000recipe.com/recipe/6945471', 'reci': ['1. 믹싱볼에 우유 20ml, 달걀 1개를 넣고 거품기로 풀어요.', '2. 바질페스토를 1숟가락 넣어 한 번 더 섞어요.', '3. 비스킷믹스를 넣고 주걱으로 고르게 섞어요.', '4. 날가루가 보이지 않으면 레몬필을 뿌려 한 덩어리로 만들어요.', '5. 반죽에 레몬필을 뿌려 한 번 더 반죽해요.', '6. 반죽을 6등분해요.', '7. 에어프라이어에 종이호일을 깔고, 180도로 12분 간 구워 완성해요.오븐 사용 시, 210도로 예열 후 15분 간 구워요.']}
# {'id': 3, 'name': '연두부부추탕 : 차가운 바람이 부는 쌀쌀한 날씨에 어울리는 뜨뜬한 국물요리 ', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/10/26/69a20edffafcf84e82ed81f3c8723cd31.png', 'ingre': [{'ingre_name': '연두부', 'ingre_count': '200', 'ingre_unit': 'g'}, {'ingre_name': '부추', 'ingre_count': '30', 'ingre_unit': 'g'}, {'ingre_name': '마늘', 'ingre_count': '3', 'ingre_unit': '쪽'}, {'ingre_name': '대파', 'ingre_count': '1/4', 'ingre_unit': '대'}, {'ingre_name': '건표고버섯', 'ingre_count': '2', 'ingre_unit': '장'}, {'ingre_name': '다시마', 'ingre_count': '3', 'ingre_unit': '장'}, {'ingre_name': '물', 'ingre_count': '3', 'ingre_unit': '종이컵'}, {'ingre_name': '소금', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '후추', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '진간장', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '참기름', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '감자전분', 'ingre_count': '2', 'ingre_unit': '숟가락'}, {'ingre_name': '물', 'ingre_count': '2', 'ingre_unit': '숟가락'}], 'url': 'https://www.10000recipe.com/recipe/6945454', 'reci': ['1. 대파는 송송 썰고, 마늘은 슬라이스한다.                     \r                             카카두 호주 캄포나무도마                            \r                             헹켈 즈윌링 스타일 아시아식도                          ', '2. 부추는 3cm 길이로 썬다.', '3. 전분물 재료를 고루 섞는다.', '4. 물기를 제거한 연두부는 1cm 두께로 썬다.', '5. 냄비에 참기름을 두르고 마늘, 대파를 볶아 향을 낸다.', '6. 물, 다시마, 표고버섯을 넣고 끓인다.다시마는 물이 끓으면 건져 주세요 ', '7. 연두부를 넣고 2분간 끓인 후 전분물을 넣는다.', '8. 부추를 넣고 한소끔 끓여 완성한다.입맛에 맞춰 소금, 후추를 넣어도 좋아요 ']}
# {'id': 4, 'name': '달콤한 간식! 에어프라이어로 만든 카스텔라디저트! 카스도스', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/10/26/e685252f821125ed58124525babf0d511.jpg', 'ingre': [{'ingre_name': '카스텔라', 'ingre_count': '1', 'ingre_unit': '개'}, {'ingre_name': '달걀노른자', 'ingre_count': '10', 'ingre_unit': '개'}, {'ingre_name': '물엿', 'ingre_count': '', 'ingre_unit': '적당량'}, {'ingre_name': '설탕', 'ingre_count': '', 'ingre_unit': '적당량'}, {'ingre_name': '코코넛가루', 'ingre_count': '', 'ingre_unit': '적당량'}, {'ingre_name': '잣가루', 'ingre_count': '', 'ingre_unit': '적당량'}, {'ingre_name': '콩가루', 'ingre_count': '', 'ingre_unit': '적당량'}], 'url': 'https://www.10000recipe.com/recipe/6945383', 'reci': ['1. 카스텔라는 갈색 부분을 제거하고 직사각형 모양으로 자른다.                     \r                             카카두 호주 캄포나무도마                          ', '2. 달걀 노른자는 잘 풀어준 후 체에 내린다.', '3. 자른 카스텔라를 노른자> 물엿 순으로 묻힌다.', '4. 에어프라이어 바스켓에 넣고 170도 온도에서 10분 뒤집어서 10분간 굽는다.', '5. 설탕, 코코넛가루, 잣가루, 콩가루를 각각 굴려 묻혀 완성한다.']}
# {'id': 5, 'name': '홈베이킹으로 따라하기 쉬운 초코쿠키레시피! 피칸초코바쿠키 ♥ ', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/10/30/66c5d252f64ef6c348323dd4d7c87c8c1.jpg', 'ingre': [{'ingre_name': '무염버터', 'ingre_count': '90', 'ingre_unit': 'g'}, {'ingre_name': '황설탕', 'ingre_count': '70', 'ingre_unit': 'g'}, {'ingre_name': '물엿', 'ingre_count': '10', 'ingre_unit': 'g'}, {'ingre_name': '소금', 'ingre_count': '1', 'ingre_unit': '꼬집'}, {'ingre_name': '달걀', 'ingre_count': '45', 'ingre_unit': 'g'}, {'ingre_name': '바닐라익스트랙', 'ingre_count': '1/2', 'ingre_unit': 't'}, {'ingre_name': '박력분', 'ingre_count': '180', 'ingre_unit': 'g'}, {'ingre_name': '베이킹파우더', 'ingre_count': '1/2', 'ingre_unit': 't'}, {'ingre_name': '피칸', 'ingre_count': '50', 'ingre_unit': 'g'}, {'ingre_name': '초코칩', 'ingre_count': '50', 'ingre_unit': 'g'}, {'ingre_name': '초코바', 'ingre_count': '1', 'ingre_unit': '개'}], 'url': 'https://www.10000recipe.com/recipe/6945363', 'reci': ['1. 볼에 무염버터를 넣고 핸드믹서로 부드럽게 푼다.                     \r                             B&C Market 핸드믹서 (핑크)                          ', '2. 황설탕, 물엿, 소금을 넣고 핸드믹서로 섞는다.', '3. 달걀과 바닐라익스트랙을 2~3회에 나누어 넣고 섞는다.', '4. 체친 가루재료를 넣고 고무주걱으로 섞는다.                     \r                             휴바트 이지레스트 아카시아 스트레이너 체망                          ', '5. 피칸, 초코칩, 초코바를 넣고 섞는다.초코바는 한입크기로 피칸은 작게 다져 넣어요.', '6. 반죽을 적당한 크기로 나누어 오븐팬에 팬닝한다.', '7. 180도 예열한 오븐에 15~20분 굽는다.', '8. 구워진 쿠키는 식힘망에 올려 식혀 완성한다.                     \r                             MESSE 코팅좋은 논스틱식힘망(40.5X25cm)                          ']}
# {'id': 6, 'name': '오븐요리 중 가장 쉬운 파피요트 대구파피요트 만들고 홈파티 준비하자! ', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/10/26/8c6bc572e7745857447107ee155cd3c11.png', 'ingre': [{'ingre_name': '대구살', 'ingre_count': '300', 'ingre_unit': 'g'}, {'ingre_name': '소금', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '올리브유', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '화이트와인', 'ingre_count': '3', 'ingre_unit': '숟가락'}, {'ingre_name': '방울토마토', 'ingre_count': '3', 'ingre_unit': '개'}, {'ingre_name': '레몬', 'ingre_count': '1', 'ingre_unit': '개'}, {'ingre_name': '버터', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '아스파라거스', 'ingre_count': '4', 'ingre_unit': '개'}, {'ingre_name': '타임', 'ingre_count': '3', 'ingre_unit': '줄'}, {'ingre_name': '로즈마리', 'ingre_count': '2', 'ingre_unit': '줄'}, {'ingre_name': '감자', 'ingre_count': '1', 'ingre_unit': '개'}], 'url': 'https://www.10000recipe.com/recipe/6945345', 'reci': ['1. 아스파라거스는 밑둥만 필러로 밀어 질긴 끝부분은 썬다.                     \r                             어반트렌드 링고 멀티 필러 그레이                           \r                             라오메뜨 이태리 천연세라믹 트레이 도마                          ', '2. 감자는 얇게 슬라이스하고, 레몬은 1/2개만 슬라이스한다.', '3. 대구살에 레몬즙, 소금, 후추, 올리브유로 밑간을 한다.', '4. 종이호일에 감자> 아스파라거스> 대구살> 레몬, 방울토마토, 버터, 로즈마리, 타임, 화이트와인, 버터, 소금, 후추를 넣는다.', '5. 종이호일을 덮은 후 가장자리를 접어 완전히 밀봉한다.', '6. 190도로 예열된 오븐에 20~25분간 구워 완성한다.                     \r                             COSTEL 2IN1 그라파이트 미니오븐 토스터 CRT-153 (그린)                          ']}
# {'id': 7, 'name': '침 고이게 만드는 그윽한 매운맛! 우유짬뽕', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/10/30/ef15ffc375ab491d7417cc287cd598b61.jpg', 'ingre': [{'ingre_name': '마늘', 'ingre_count': '5', 'ingre_unit': '쪽'}, {'ingre_name': '양파', 'ingre_count': '1/4', 'ingre_unit': '개'}, {'ingre_name': '청양고추', 'ingre_count': '2', 'ingre_unit': '개'}, {'ingre_name': '마른고추', 'ingre_count': '3', 'ingre_unit': '개'}, {'ingre_name': '홍합', 'ingre_count': '8', 'ingre_unit': '개'}, {'ingre_name': '새우', 'ingre_count': '4', 'ingre_unit': '마리'}, {'ingre_name': '오징어', 'ingre_count': '1/2', 'ingre_unit': '마리'}, {'ingre_name': '식용유', 'ingre_count': '', 'ingre_unit': '적당량'}, {'ingre_name': '생면', 'ingre_count': '1', 'ingre_unit': '인분'}, {'ingre_name': '우유', 'ingre_count': '300', 'ingre_unit': 'ml'}, {'ingre_name': '생크림', 'ingre_count': '100', 'ingre_unit': 'ml'}, {'ingre_name': '소금', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '후추', 'ingre_count': '', 'ingre_unit': '약간'}], 'url': 'https://www.10000recipe.com/recipe/6945312', 'reci': ['1. 마늘은 편 썰기 / 양파는 채 썰기 / 청양고추는 송송 썰기 / 마른 고추는 작게 썰기 해요.', '2. 홍합과 새우는 깨끗하게 손질하고, 오징어는 링 모양으로 썰어요.', '3. 냄비에 식용유를 두르고, 마늘을 넣어 볶다가 향이 나면 양파, 청양고추, 마른 고추를 넣어 센 불에 3분 정도 볶아요.', '4. 홍합, 새우, 오징어를 넣어 3분 정도 더 볶아요.', '5. 재료가 익어 어우러지면 우유와 생크림을 넣고 중간불로 5분 정도 끓여요.우유는 센불에 끓이면 넘치기 쉬우니 뚜껑을 열고 불을 조절해가며 끓여요.', '6. 생면은 삶아서 체로 물기를 빼고, 소스에 넣어 3분 정도 끓여요. 소금과 후춧가루로 간을 더해요.']}
# {'id': 8, 'name': '단호박으로 노오븐 치즈케이크 만들기! 할로윈 단호박치즈케이크 만들기 ♥', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/10/28/775e6fa6bd7455989d3276b75070ede81.jpg', 'ingre': [{'ingre_name': '오레오', 'ingre_count': '10', 'ingre_unit': '개'}, {'ingre_name': '녹인무염버터', 'ingre_count': '25', 'ingre_unit': 'g'}, {'ingre_name': '크림치즈', 'ingre_count': '250', 'ingre_unit': 'g'}, {'ingre_name': '설탕', 'ingre_count': '70', 'ingre_unit': 'g'}, {'ingre_name': '단호박퓨레', 'ingre_count': '150', 'ingre_unit': 'g'}, {'ingre_name': '생크림', 'ingre_count': '250', 'ingre_unit': 'g'}, {'ingre_name': '시나몬파우더', 'ingre_count': '1/4', 'ingre_unit': 't'}, {'ingre_name': '판젤라틴', 'ingre_count': '7', 'ingre_unit': 'g'}, {'ingre_name': '물', 'ingre_count': '1', 'ingre_unit': 'T'}, {'ingre_name': '코코아파우더', 'ingre_count': '', 'ingre_unit': '약간'}], 'url': 'https://www.10000recipe.com/recipe/6945295', 'reci': ['1. 오레오는 크림을 제거하고 잘게 부숴 녹인 버터를 넣고 잘 섞는다.', '2. 투명용기에 쿠키반죽을 넣고 스푼이나 손으로 꾹꾹 눌러 바닥을 만든 후 냉장고에 넣어 굳힌다.', '3. 볼에 얼음물을 준비하고 판젤라틴을 한장씩 넣고 불린다.', '4. 볼에 크림치즈를 넣고 거품기로 가볍게 풀고 설탕을 넣고 섞는다.                     \r                             B&C Market 베이킹가전 핸드믹서 핑크                          ', '5. 단호박퓨레와 시나몬파우더를 넣고 섞는다.단호박퓨레는 단호박을 삶아 곱게 갈아 사용해요.', '6. 생크림은 60% 정도의 농도로 묽게 휘핑한다.', '7. 휘핑한 생크림을 크림치즈 반죽에 넣고 휘퍼로 섞는다.', '8. 얼음물에 불린 젤라틴을 건져 물기를 짜고 물 한큰술을 넣고 녹인다.전자레인지에 15~20초 정도 돌려 완전히 녹여요.', '9. 크림치즈 반죽에 녹인 젤라틴을 넣고 섞는다.                     \r                             거품기(스테인레스/소/29cm)                          ', '10. 쿠키를 깐 틀에 단호박크림치즈 반죽을 채우고 윗면을 평평하게 정리 후 냉장고에 넣어 30분 이상 굳힌다.', '11. 코코아파우더를 뿌리거나 할로윈 장식으로 마무리한다.']}
# {'id': 9, 'name': '달달~하고 든든~한 우유쌀푸딩', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/10/29/9bd552ba3ee6946413d406de89b6bae21.jpg', 'ingre': [{'ingre_name': '바나나', 'ingre_count': '1/2', 'ingre_unit': '개'}, {'ingre_name': '우유', 'ingre_count': '400', 'ingre_unit': 'ml'}, {'ingre_name': '찬밥', 'ingre_count': '200', 'ingre_unit': 'g'}, {'ingre_name': '설탕', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '달걀노른자', 'ingre_count': '1', 'ingre_unit': '개'}, {'ingre_name': '버터', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '소금', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '바나나', 'ingre_count': '1/2', 'ingre_unit': '개'}, {'ingre_name': '견과류', 'ingre_count': '', 'ingre_unit': '등'}], 'url': 'https://www.10000recipe.com/recipe/6945255', 'reci': ['1. 바나나는 껍질을 벗겨 포크로 곱게 으깨고, 우유 2컵, 설탕 1숟가락과 섞어요.', '2. 밥을 넣은 다음 중간불에 10분 정도 끓여요.', '3. 불을 끄고 버터, 달걀노른자를 넣어 재빨리 풀고, 차게 식혀요.', '4. 차게 식은 푸딩을 담고 바나나, 견과류 등을 올려 완성해요.']}
# {'id': 10, 'name': '할로윈특집 베이킹! 이름만 으스스 귀여운 고스트컵케이크 ♥', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/10/26/0325285b8785478598a11e79192ea7be1.jpg', 'ingre': [{'ingre_name': '무염버터', 'ingre_count': '115', 'ingre_unit': 'g'}, {'ingre_name': '설탕', 'ingre_count': '100', 'ingre_unit': 'g'}, {'ingre_name': '소금', 'ingre_count': '1', 'ingre_unit': '꼬집'}, {'ingre_name': '달걀', 'ingre_count': '120', 'ingre_unit': 'g'}, {'ingre_name': '바닐라익스트랙', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '박력분', 'ingre_count': '100', 'ingre_unit': 'g'}, {'ingre_name': '코코아파우더', 'ingre_count': '30', 'ingre_unit': 'g'}, {'ingre_name': '베이킹파우더', 'ingre_count': '2', 'ingre_unit': 'g'}, {'ingre_name': '우유', 'ingre_count': '20', 'ingre_unit': 'g'}, {'ingre_name': '크림치즈', 'ingre_count': '200', 'ingre_unit': 'g'}, {'ingre_name': '무염버터', 'ingre_count': '100', 'ingre_unit': 'g'}, {'ingre_name': '슈가파우더', 'ingre_count': '100', 'ingre_unit': 'g'}, {'ingre_name': '체리잼', 'ingre_count': '', 'ingre_unit': '적당량'}, {'ingre_name': '크리스탈슈가', 'ingre_count': '', 'ingre_unit': '적당량'}, {'ingre_name': '초코펜', 'ingre_count': '', 'ingre_unit': '적당량'}, {'ingre_name': '젤리', 'ingre_count': '', 'ingre_unit': '적당량'}], 'url': 'https://www.10000recipe.com/recipe/6945228', 'reci': ['1. 볼에 무염버터와 설탕, 소금을 넣고 핸드믹서로 부드럽게 푼다.', '2. 달걀과 바닐라익스트랙을 잘 섞은 후 2~3회에 나누어 넣으면서 핸드믹서로 섞는다.                     \r                             B&C Market 베이킹가전 BEST상품 기획전                          ', '3. 박력분, 코코아파우더, 베이킹 파우더를 함께 체쳐서 넣고 고무주걱으로 섞는다.', '4. 가루가 약간 남아있을 때 우유를 넣고 섞는다.', '5. 반죽을 짤주머니에 담고 유산지를 깐 틀에 채운다.                     \r                             MESSE코팅좋은 머핀틀(6구/26X18cm)                          ', '6. 175도로 예열한 오븐에 25~30분 굽는다.', '7. 구워진 초코케이크는 식힘망에 식힌다.                     \r                             MESSE 코팅좋은 논스틱식힘망(40.5X25cm)                          ', '8. 볼에 크림치즈와 버터를 넣고 핸드믹서로 부드럽게 푼다.', '9. 슈가파우더를 넣고 잘 섞는다.식용색소를 넣고 다양하게 색상을 만들어도 좋아요.', '10. 케이크 가운데를 구멍을 만든 후 체리 잼을 채운다.', '11. 크림치즈프로스팅을 올리고 크리스탈 슈가를 뿌린 후 유령모양으로 크림을 짜서 완성한다.']}
# {'id': 11, 'name': '줄줄이 소시지와 치즈를 넣어 만든 에어프라이어표 밥도그 ♥', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/10/26/5c2614af7c886480e1e5e3d7f5de30aa1.png', 'ingre': [{'ingre_name': '밥', 'ingre_count': '2', 'ingre_unit': '공기'}, {'ingre_name': '당근', 'ingre_count': '1/4', 'ingre_unit': '개'}, {'ingre_name': '피망', 'ingre_count': '1/2', 'ingre_unit': '개'}, {'ingre_name': '밀가루', 'ingre_count': '1/2', 'ingre_unit': '종이컵'}, {'ingre_name': '달걀', 'ingre_count': '1', 'ingre_unit': '개'}, {'ingre_name': '빵가루', 'ingre_count': '1/2', 'ingre_unit': '종이컵'}, {'ingre_name': '소시지', 'ingre_count': '4', 'ingre_unit': '개'}, {'ingre_name': '스트링치즈', 'ingre_count': '1', 'ingre_unit': '개'}, {'ingre_name': '식용유', 'ingre_count': '', 'ingre_unit': '적당량'}, {'ingre_name': '굴소스', 'ingre_count': '2', 'ingre_unit': '숟가락'}, {'ingre_name': '소금', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '후추', 'ingre_count': '', 'ingre_unit': '약간'}], 'url': 'https://www.10000recipe.com/recipe/6945168', 'reci': ['1. 당근, 피망은 차퍼로 잘게 다진다.', '2. 밥에 다진 채소와 양념 재료를 넣고 잘 섞는다.', '3. 섞은 밥 속에 소시지, 스트링 치즈를 넣고 감싸 모양을 잡는다.', '4. 밀가루 > 달걀물 > 빵가루 순으로 묻힌 후 에어프라이어 바스켓에 넣는다.', '5. 식용유를 넉넉히 뿌린 후 190도 온도에서 15분간 구워 완성한다.']}
# {'id': 12, 'name': '태국에서 먹는 태국식 닭튀김 ไก่ทอด  까이텃  만들면서 태국여행 떠나자! ', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/10/26/5802c758cb1127a8d07d854fac0085ce1.jpg', 'ingre': [{'ingre_name': '닭', 'ingre_count': '1', 'ingre_unit': '마리'}, {'ingre_name': '마늘', 'ingre_count': '5', 'ingre_unit': '개'}, {'ingre_name': '코리앤더씨드', 'ingre_count': '1/4', 'ingre_unit': '숟가락'}, {'ingre_name': '굴소스', 'ingre_count': '2', 'ingre_unit': '숟가락'}, {'ingre_name': '피쉬소스', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '설탕', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '통후추', 'ingre_count': '15', 'ingre_unit': '알'}, {'ingre_name': '쌀가루', 'ingre_count': '1', 'ingre_unit': '종이컵'}, {'ingre_name': '튀김가루', 'ingre_count': '1', 'ingre_unit': '종이컵'}, {'ingre_name': '소금', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '무', 'ingre_count': '1/6', 'ingre_unit': '개'}, {'ingre_name': '당근', 'ingre_count': '1/6', 'ingre_unit': '개'}, {'ingre_name': '식초', 'ingre_count': '1/2', 'ingre_unit': '종이컵'}, {'ingre_name': '설탕', 'ingre_count': '1/4', 'ingre_unit': '종이컵'}, {'ingre_name': '소금', 'ingre_count': '1', 'ingre_unit': '숟가락'}], 'url': 'https://www.10000recipe.com/recipe/6945097', 'reci': ['1. 무, 당근을 6cm 길이로 채썬다.                     \r                             네오플램 피카 쁘띠웍                          ', '2. 냄비에 식초, 설탕, 소금을 넣고 설탕이 녹을 때까지 끓인다.', '3. 무, 당근에 부어 한김 식으면 냉장고에서 2시간이상 절인다.', '4. 절구에 마늘, 통후추,코리앤더씨드를 빻은 후 굴소스, 피쉬소스, 설탕을 넣고 마리네이드소스를 만든다.                     \r                             제이미올리버 돌절구                          ', '5. 손질한 닭에 마리네이드소스를 고루 바른다.', '6. 쌀가루, 튀김가루, 소금을 잘 섞은 후 마리네이드 된 닭에 반죽옷을 입힌다.', '7. 180도로 예열된 기름에 2번 튀겨 무절임과 곁들여 완성한다.']}
# {'id': 13, 'name': '브런치 메뉴 원탑! 촉촉하고 달콤한 프렌치토스트', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/10/26/f39a4851ef50842bc260161a477bc4191.jpg', 'ingre': [{'ingre_name': '식빵', 'ingre_count': '2', 'ingre_unit': '장'}, {'ingre_name': '달걀', 'ingre_count': '2', 'ingre_unit': '개'}, {'ingre_name': '우유', 'ingre_count': '1', 'ingre_unit': '종이컵'}, {'ingre_name': '소금', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '버터', 'ingre_count': '1/2', 'ingre_unit': '숟가락'}, {'ingre_name': '연유', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '슈가파우더', 'ingre_count': '', 'ingre_unit': '약간'}], 'url': 'https://www.10000recipe.com/recipe/6945045', 'reci': ['1. 볼에 달걀, 우유, 소금을 넣어 달걀물을 만들어요.', '2. 달걀물에 식빵을 충분히 담가 달걀물을 입혀요.', '3. 예열된 팬에 버터를 넣어 녹인 후, 달걀물을 입힌 식빵을 앞뒤로 노릇하게 구워요.', '4. 그릇에 담아 연유를 뿌리고 슈가파우더를 뿌려 완성해요.기호에 따라 과일, 견과류 등을 곁들여요.']}
# {'id': 14, 'name': '밀크잼 3가지! 커피잼, 밀크티잼, 초코잼을 집에서 만드는 방법 ♥', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/10/26/365470f841c15309b6bde48136d7383d1.png', 'ingre': [{'ingre_name': '우유', 'ingre_count': '2', 'ingre_unit': '종이컵'}, {'ingre_name': '생크림', 'ingre_count': '1', 'ingre_unit': '종이컵'}, {'ingre_name': '설탕', 'ingre_count': '1/3', 'ingre_unit': '종이컵'}, {'ingre_name': '바닐라익스트릭', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '얼그레이티백', 'ingre_count': '2', 'ingre_unit': '개'}, {'ingre_name': '우유', 'ingre_count': '2', 'ingre_unit': '종이컵'}, {'ingre_name': '생크림', 'ingre_count': '1', 'ingre_unit': '종이컵'}, {'ingre_name': '설탕', 'ingre_count': '1/3', 'ingre_unit': '종이컵'}, {'ingre_name': '연유', 'ingre_count': '2', 'ingre_unit': '숟가락'}, {'ingre_name': '커피가루', 'ingre_count': '2', 'ingre_unit': '숟가락'}, {'ingre_name': '우유', 'ingre_count': '2', 'ingre_unit': '종이컵'}, {'ingre_name': '생크림', 'ingre_count': '1', 'ingre_unit': '종이컵'}, {'ingre_name': '설탕', 'ingre_count': '2', 'ingre_unit': '숟가락'}, {'ingre_name': '코코아파우더', 'ingre_count': '2', 'ingre_unit': '숟가락'}, {'ingre_name': '다크초콜릿', 'ingre_count': '1/2', 'ingre_unit': '종이컵'}], 'url': 'https://www.10000recipe.com/recipe/6945027', 'reci': ['1. 유리병을 끓는 물에 소독한 후 물기를 제거한다.', '2. 우유, 생크림을 넣고 끓인다.얼그레이밀크잼은 티백, 우유, 생크림을 같이 넣고 끓여주세요   \r                             네오플램 피카 편수냄비                          ', '3. 끓기 시작하면 나머지 재료를 각각 넣고 농도가 날 때 까지 약불로 끓인다.', '4. 유리병에 담아 충분히 식힌 후 뚜껑을 닫아 냉장고에 보관한다.2주일 이내로 섭취해주세요 ']}
# {'id': 15, 'name': '새우토마토스튜 ♥ 이탈리아식 카치아토레를 새우로 만들어요', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/10/19/0be1100802542ac1fc14bbc5801ddab81.jpg', 'ingre': [{'ingre_name': '새우', 'ingre_count': '6', 'ingre_unit': '마리'}, {'ingre_name': '모시조개', 'ingre_count': '1', 'ingre_unit': '종이컵'}, {'ingre_name': '방울토마토', 'ingre_count': '3', 'ingre_unit': '개'}, {'ingre_name': '마늘', 'ingre_count': '6', 'ingre_unit': '알'}, {'ingre_name': '양파', 'ingre_count': '1/2', 'ingre_unit': '개'}, {'ingre_name': '노란파프리카', 'ingre_count': '1/2', 'ingre_unit': '개'}, {'ingre_name': '페페로치니', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '홀토마토', 'ingre_count': '2', 'ingre_unit': '종이컵'}, {'ingre_name': '고추장', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '그린올리브', 'ingre_count': '6', 'ingre_unit': '알'}, {'ingre_name': '소금', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '후추', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '그라노파다노치즈', 'ingre_count': '', 'ingre_unit': '약간'}], 'url': 'https://www.10000recipe.com/recipe/6944965', 'reci': ['1. 마늘은 반으로 자르고, 양파, 파프리카는 한입크기로 썬다.                     \r                             파뷔에 마호가니 원목 도마                          ', '2. 냄비에 올리브유를 두르고 새우를 볶아 접시에 덜어둔다.                     \r                             스타우브 원형 꼬꼬떼 22cm 바질그린(ST102285)                          ', '3. 새우를 볶은 냄비에 올리브유를 두르고 마늘, 페퍼로치니을 넣고 볶아 향을 낸다.', '4. 양파, 파프리카를 볶다가, 홀토마토, 고추장, 그린올리브, 모시조개를 넣고 끓인다.', '5. 조개가 입을 벌리면 방울토마토, 구운 새우, 소금, 후추를 넣고 끓인다.', '6. 그라나파다노, 올리브유를 뿌려 완성한다.']}
# {'id': 16, 'name': '추억의 학교앞 간식! 피카츄꼬치 만들기! 떡꼬치 소스는 꼭 듬뿍', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/10/19/94edf257e3ad64985b80875125a20eb91.jpg', 'ingre': [{'ingre_name': '돼지고기다짐육', 'ingre_count': '2', 'ingre_unit': '종이컵'}, {'ingre_name': '닭다리살', 'ingre_count': '1', 'ingre_unit': '개'}, {'ingre_name': '달걀', 'ingre_count': '1/2', 'ingre_unit': '개'}, {'ingre_name': '다진마늘', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '청주', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '후추', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '소금', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '식용유', 'ingre_count': '', 'ingre_unit': '넉넉히'}, {'ingre_name': '밀가루', 'ingre_count': '1/2', 'ingre_unit': '종이컵'}, {'ingre_name': '달걀', 'ingre_count': '1', 'ingre_unit': '개'}, {'ingre_name': '빵가루', 'ingre_count': '1', 'ingre_unit': '종이컵'}, {'ingre_name': '케찹', 'ingre_count': '5', 'ingre_unit': '숟가락'}, {'ingre_name': '고추장', 'ingre_count': '1', 'ingre_unit': '숟가락'}, {'ingre_name': '물엿', 'ingre_count': '2', 'ingre_unit': '숟가락'}, {'ingre_name': '설탕', 'ingre_count': '2', 'ingre_unit': '숟가락'}, {'ingre_name': '설탕', 'ingre_count': '', 'ingre_unit': '적당량'}, {'ingre_name': '머스터드', 'ingre_count': '', 'ingre_unit': '적당량'}], 'url': 'https://www.10000recipe.com/recipe/6944924', 'reci': ['1. 믹서에 재료를 넣어 간다.', '2. 간 재료를 잘 치댄 후 피카츄 모양을 만든다.모양을 만든 후 냉동실에 살짝 얼려주세요.', '3. 만들어 둔 피카츄를 밀가루>달걀물>빵가루 순으로 묻힌다.', '4. 예열 된 기름에 피카츄를 넣어 노릇하게 튀긴 후 꼬지를 꽂는다.', '5. 양념 재료를 잘 섞어 소스를 만든다.', '6. 튀긴 피카츄 꼬지에 소스를 발라 완성한다.설탕, 머스터드를 뿌려 먹어도 맛있어요.']}
# {'id': 17, 'name': '톡톡! 리틀포레스트에 나온 크렘브륄레 ♥ 가을 밤으로 찐하게 만들기', 'img': 'https://recipe1.ezmember.co.kr/cache/recipe/2020/10/19/85ec130a778d1bb1be133df2682aaf161.png', 'ingre': [{'ingre_name': '생크림', 'ingre_count': '450', 'ingre_unit': 'g'}, {'ingre_name': '바닐라빈', 'ingre_count': '1/2', 'ingre_unit': '개'}, {'ingre_name': '밤페이스트', 'ingre_count': '80', 'ingre_unit': 'g'}, {'ingre_name': '우유', 'ingre_count': '100', 'ingre_unit': 'g'}, {'ingre_name': '설탕', 'ingre_count': '40', 'ingre_unit': 'g'}, {'ingre_name': '소금', 'ingre_count': '1', 'ingre_unit': '꼬집'}, {'ingre_name': '달걀노른자', 'ingre_count': '5', 'ingre_unit': '개'}, {'ingre_name': '황설탕', 'ingre_count': '', 'ingre_unit': '약간'}, {'ingre_name': '맛밤', 'ingre_count': '', 'ingre_unit': '약간'}], 'url': 'https://www.10000recipe.com/recipe/6944859', 'reci': ['1. 맛밤은 1/4등분하고 오븐용기에 담아둔다.                     \r                             카카두 프리미엄 캄포나무 도마                          ', '2. 볼에 밤페이스트를 넣고 우유를 조금씩 넣으면서 부드럽게 풀어준다.', '3. 냄비에 부드럽게 풀어준 밤페이스트와 생크림, 바닐라빈을 넣고 살짝 데운 후 식힌다.', '4. 다른 볼에 달걀노른자와 설탕,소금을 넣고 손거품기로 잘 섞는다.', '5. 데운 생크림을을 노른자에 조금씩 넣으면서 섞는다.                     \r                             거품기(스테인레스/소/29cm)                          ', '6. 체에 한번 거른 후 오븐용기에 담는다.                     \r                             휴바트 이지레스트 아카시아 스트레이너 체반                          ', '7. 중탕으로 150도 오븐에 30~40분 익힌다.                     \r                             오븐팬(양면코팅)                          ', '8. 차갑게 식힌 후 황설탕을 위에 뿌린 후 토치로 설탕을 태워 완성한다.']}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-4b831cd5f33c> in <module>
#      44     url = 'https://www.10000recipe.com'
#      45     url = url + url_str
# ---> 46     response = requests.get(url)
#      47     html = response.text
#      48     soup = BeautifulSoup(html, 'html.parser')
#
# e:\python3.7\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# e:\python3.7\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# e:\python3.7\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# e:\python3.7\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# e:\python3.7\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# e:\python3.7\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# e:\python3.7\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# e:\python3.7\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# e:\python3.7\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# e:\python3.7\lib\http\client.py in getresponse(self)
#    1367         try:
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#    1371                 self.close()
#
# e:\python3.7\lib\http\client.py in begin(self)
#     308         # read until we get a non-100 response
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#     312                 break
#
# e:\python3.7\lib\http\client.py in _read_status(self)
#     269
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#     273             raise LineTooLong("status line")
#
# e:\python3.7\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# e:\python3.7\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# e:\python3.7\lib\ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import re
import json
import urllib.request

num_id = 0
food_dicts = []
url = 'https://www.10000recipe.com/recipe/6881099'
response = requests.get(url)
html = response.text
soup = BeautifulSoup(html, 'html.parser')

#menu name
res = soup.find('div', 'view2_summary')
res = res.find('h3')
menu_name = res.get_text().replace('\n',' ').replace('"','')

#menu image
res = soup.find('div', 'centeredcrop')
res = res.find('img')
menu_img = res.get('src')

# ingredients
res = soup.find('div','ready_ingre3')
ingre_dict = {}
ingre_list = []
try:
    for n in res.find_all('ul'):
        for tmp in n.find_all('li'):
            ingredient_name = tmp.get_text().replace('\n','').replace(' ','')
            count = tmp.find('span')
            ingredient_tmp = count.get_text()
            ingredient_name = re.sub(ingredient_tmp, '',ingredient_name)

            ingre_list.append(ingredient_name)
except(AttributeError):
    pass

# # recipe
# recipe_list = []
# res = soup.find('div','view_step')
# ind = 1
# for n in res.find_all('div', 'view_step_cont'):
#     recipe_step_txt = n.get_text().replace('\n',' ')
#     recipe_list.append(str(ind) + '. ' + recipe_step_txt)
#     ind += 1

## contents
contents = []
res = soup.find('div','view_step')
print(res)

food_dict = {"id":num_id,
            "name":menu_name,
            "thumbnail":menu_img,
            "ingre":ingre_list,
            "url": url}
num_id += 1
food_dicts.append(food_dict)
print(food_dict)
# Out:
# <div class="view_step">
# <div class="best_tit">
# <b>조리순서</b><span>Steps</span>
# <div class="best_tit_rmn">
# <a href="javascript:void(0);" onclick="chgViewStep(1)"><img alt="이미지크게보기" id="tabStepView1" src="https://recipe1.ezmember.co.kr/img/mobile/tab_view1.png"/></a>
# <a href="javascript:void(0);" onclick="chgViewStep(2)"><img alt="텍스트만보기" id="tabStepView2" src="https://recipe1.ezmember.co.kr/img/mobile/tab_view2.png"/></a>
# <a href="javascript:void(0);" onclick="chgViewStep(3)"><img alt="이미지작게보기" id="tabStepView3" src="https://recipe1.ezmember.co.kr/img/mobile/tab_view3_on.png"/></a>
# <button class="btn btn-sm btn-default" onclick="location.href='/recipe/6881099?seq=6881099&amp;is_origin=y'" style="margin-left:10px;">원본보기</button>
# </div>
# </div>
# <div class="view_step_cont media step1" id="stepDiv1"><div class="media-body" id="stepdescr1">팽이버섯은 밑둥을 잘라내고 씻어주시고 깻잎도 흐르는물에 씻어주세요<p class="step_add add_tip2">저는 깻잎이 커서 반으로 잘라서 사용!<br>
# 작으면 1장을 통채로 쓰시면됩니다</br></p></div><div id="stepimg1"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/2d50563292f33e36af5e97d7a77c5c541.jpg"/></div></div><div class="view_step_cont media step2" id="stepDiv2"><div class="media-body" id="stepdescr2">차돌박이 위에깻잎을 올리고</div><div id="stepimg2"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/3777dc9f30d34604fcaad6754c2ecbea1.jpg"/></div></div><div class="view_step_cont media step3" id="stepDiv3"><div class="media-body" id="stepdescr3">그위에 팽이버섯을 올려준뒤</div><div id="stepimg3"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/934c09d9c92ed30bc4dc7a060fcad5601.jpg"/></div></div><div class="view_step_cont media step4" id="stepDiv4"><div class="media-body" id="stepdescr4">돌돌 말아주기만하면 완성이에요</div><div id="stepimg4"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/e783e548fe5774486813f634bbb4deba1.jpg"/></div></div><div class="view_step_cont media step5" id="stepDiv5"><div class="media-body" id="stepdescr5">만드는 방법 완전 간단하죠?</div><div id="stepimg5"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/38e8a30875dda2a3c02086a5fc55019a1.jpg"/></div></div><div class="view_step_cont media step6" id="stepDiv6"><div class="media-body" id="stepdescr6">냄비에 숙주나물을 한주먹 깔고</div><div id="stepimg6"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/5900ea4c3f67226dbb9a26e282cfce631.jpg"/></div></div><div class="view_step_cont media step7" id="stepDiv7"><div class="media-body" id="stepdescr7">차돌박이를 올려 10분간 쪄주면 끝<p class="step_add add_tip2">차돌박이 말린이음새 부분이 아래로 가게 두고 찌면 풀어지지않아요</p></div><div id="stepimg7"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/5a2355ce81a553cb88d4757f0d534c6b1.jpg"/></div></div><div class="view_step_cont media step8" id="stepDiv8"><div class="media-body" id="stepdescr8">차돌박이찜이 완성되는 사이 소스를 만들어볼게요!<br/>
# 처음엔 된장이랑 마요네즈? 하실텐데 드셔보시면 고기랑 정말 잘어울리는 소스!</div><div id="stepimg8"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/472e3653c042ffcdc80de9c4d658aefa1.jpg"/></div></div><div class="view_step_cont media step9" id="stepDiv9"><div class="media-body" id="stepdescr9">분량의 재료들을 잘섞어주시면되구요<br/>
# 미소된장이 없으시다면 집된장 말고 시판된장 싱거운걸 사용하셔도 됩니다</div><div id="stepimg9"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/300febca4f01ab9f6b3d34b520d033481.jpg"/></div></div><div class="view_step_cont media step10" id="stepDiv10"><div class="media-body" id="stepdescr10">차돌박이 찜기에 넣고 소스만들면 그사이 차돌박이찜 완성입니다<br/>
# 금새 익기때문에 정말 초스피드로 완성할수있는 요리에요</div><div id="stepimg10"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/f95a06a40fdcd99d5d8c9be370ebf9c91.jpg"/></div></div><div class="view_step_cont media step11" id="stepDiv11"><div class="media-body" id="stepdescr11">예쁘게 그릇에 담아주면 끝!</div><div id="stepimg11"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/4f354c31dd6a06d50380e84c437b2f831.jpg"/></div></div><div class="view_step_cont media step12" id="stepDiv12"><div class="media-body" id="stepdescr12">된장마요소스에 콕 찍어먹으면 정말 맛있답니다 <br/>
# 강력추천!</div><div id="stepimg12"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/94a56c0968c7d1921b0a9b2a3c722b681.jpg"/></div></div> <!-- 레시피 스텝 하단 광고 -->
# <div id="divEzadArea_recipe_view_step_bottom" style="display:none; z-index:100000;padding-left:10px;padding-right:20px;padding-top:5px;"><div id="EZAD-view_step_bottom"></div></div>
# <script>
#         var _ezad_params = {app_id:'web.com.ezhld.recipe',cmd_sub:'recipe_view_step_bottom',recipe_seq:'6881099',dev_mode:false};
#         if(_EZAD.getCookie('_ezad_hide_'+_ezad_params.cmd_sub) == '') { var s2 = document.createElement('script'); s2.type = "text/javascript"; s2.src = "//api.ezadsystem.com/api/api_kwd.html?cmd=ez_web&cmd_sub="+_ezad_params.cmd_sub+"&aid="+_ezad_params.app_id+"&recipe_seq="+_ezad_params.recipe_seq; document.getElementById('EZAD-view_step_bottom').appendChild(s2);}
#         </script>
# <div class="carousel slide" data-ride="carousel" id="completeimgs" style="width:755px;margin:0 70px 32px;">
# <ol class="carousel-indicators">
# <li class="active" data-slide-to="0" data-target="#completeimgs"></li>
# <li data-slide-to="1" data-target="#completeimgs"></li>
# <li data-slide-to="2" data-target="#completeimgs"></li>
# <li data-slide-to="3" data-target="#completeimgs"></li>
# </ol>
# <div class="carousel-inner" role="listbox">
# <div class="item active"><div class="carouItem centercrop"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/d6c24fadf0ca19fa1cbc4e83afdec8d01.jpg"/></div></div>
# <div class="item"><div class="carouItem centercrop"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/8b756c052017302f972bc0d9cb1014b71.jpg"/></div></div>
# <div class="item"><div class="carouItem centercrop"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/399cca42359a0a49e8e6cfdbe11ed5231.jpg"/></div></div>
# <div class="item"><div class="carouItem centercrop"><img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/45998ec82a055460a3176210769f3eda1.jpg"/></div></div>
# </div>
# <a class="left carousel-control" data-slide="prev" href="#completeimgs" role="button">
# <span aria-hidden="true" class="glyphicon glyphicon-chevron-left"></span>
# </a>
# <a class="right carousel-control" data-slide="next" href="#completeimgs" role="button">
# <span aria-hidden="true" class="glyphicon glyphicon-chevron-right"></span>
# </a>
# </div>
# <div class="sp_pdt_wrap"><div class="sp_pdt_tit"><img src="https://recipe1.ezmember.co.kr/img/mobile/icon_pdt2.png" width="26"/><b>레시피와 관련된 상품</b><a href="javascript:viewGoodsCarousel('recipe_view_join_step_bottom');">더보기</a></div><div class="swiper-container2" style="position: relative;padding: 10px 0 0 0;margin-left: 8px;width: 800px;overflow:hidden;text-align:center;"><div class="swiper-wrapper"> <div class="goods_1000006254 swiper-slide" style="width:150px;">
# <a href="https://shop.10000recipe.com/goods/goods_view.php?goodsNo=1000006254&amp;utm_source=10k_recipe&amp;utm_medium=recipe_view_join_step_bottom&amp;utm_campaign=미식가 이현우 우삼겹구이 15팩(2.7kg) + 특제소스 2병" onclick="doGoodsClickLog(51190542,'recipe_view_join_step_bottom')" target="_blank">
# <div class="swiper-substance">
# <div class="sp_pdt_img"><img src="https://recipe1.ezmember.co.kr/cache/data/goods/20/02/09/1000006254/1000006254_magnify_097.jpg"/></div>
# <div class="unity_cont">
# <p class="cont_tit line2">미식가 이현우 우삼겹구이 15팩(2.7kg) + 특제소스 2병</p>
# <div class="price_box">
# <strong class="price">58,900<small>원</small></strong>
# <span class="buyer">129개 구매</span>
# </div>
# <p class="cont_star">
# <span class="star_img">
# <img src="https://recipe1.ezmember.co.kr/img/mobile/icon_star2_on.png"/>
# <img src="https://recipe1.ezmember.co.kr/img/mobile/icon_star2_on.png"/>
# <img src="https://recipe1.ezmember.co.kr/img/mobile/icon_star2_on.png"/>
# <img src="https://recipe1.ezmember.co.kr/img/mobile/icon_star2_on.png"/>
# <img src="https://recipe1.ezmember.co.kr/img/mobile/icon_star2_on.png"/>
# </span>
# <span class="star_ea">(20)</span>
# </p>
# </div>
# </div>
# </a>
# </div>
# <div class="goods_1000005010 swiper-slide" style="width:150px;">
# <a href="https://shop.10000recipe.com/goods/goods_view.php?goodsNo=1000005010&amp;utm_source=10k_recipe&amp;utm_medium=recipe_view_join_step_bottom&amp;utm_campaign=20년전통 수제 차돌뒷고기 1근 !!" onclick="doGoodsClickLog(51190543,'recipe_view_join_step_bottom')" target="_blank">
# <div class="swiper-substance">
# <div class="sp_pdt_img"><img src="https://recipe1.ezmember.co.kr/cache/data/goods/19/12/51/1000005010/1000005010_magnify_089.jpg"/></div>
# <div class="unity_cont">
# <p class="cont_tit line2">20년전통 수제 차돌뒷고기 1근 !!</p>
# <div class="price_box">
# <strong class="price">9,900<small>원</small></strong>
# <span class="buyer">88개 구매</span>
# </div>
# <p class="cont_star">
# <span class="star_img">
# <img src="https://recipe1.ezmember.co.kr/img/mobile/icon_star2_on.png"/>
# <img src="https://recipe1.ezmember.co.kr/img/mobile/icon_star2_on.png"/>
# <img src="https://recipe1.ezmember.co.kr/img/mobile/icon_star2_on.png"/>
# <img src="https://recipe1.ezmember.co.kr/img/mobile/icon_star2_on.png"/>
# <img src="https://recipe1.ezmember.co.kr/img/mobile/icon_star2.png"/>
# </span>
# <span class="star_ea">(1)</span>
# </p>
# </div>
# </div>
# </a>
# </div>
# <div class="goods_1000007472 swiper-slide" style="width:150px;">
# <a href="https://shop.10000recipe.com/goods/goods_view.php?goodsNo=1000007472&amp;utm_source=10k_recipe&amp;utm_medium=recipe_view_join_step_bottom&amp;utm_campaign=[신선마켓] 미국산 차돌박이 500g" onclick="doGoodsClickLog(53675096,'recipe_view_join_step_bottom')" target="_blank">
# <div class="swiper-substance">
# <div class="sp_pdt_img"><img src="https://recipe1.ezmember.co.kr/cache/data/goods/20/05/20/1000007472/1000007472_magnify_015.jpg"/></div>
# <div class="unity_cont">
# <p class="cont_tit line2">[신선마켓] 미국산 차돌박이 500g</p>
# <div class="price_box">
# <strong class="price">16,800<small>원</small></strong>
# <span class="buyer">3개 구매</span>
# </div>
# </div>
# </div>
# </a>
# </div>
# </div></div><div class="swiper-button-next swiper-button-black" style="right:15px;filter:alpha(opacity=30); opacity:0.3;"></div><div class="swiper-button-prev swiper-button-black" style="left:15px;filter:alpha(opacity=30); opacity:0.3;"></div></div> <script>
#     doGoodsReadLog('6881099','recipe_view_join_step_bottom',0,'51190542,51190543,53675096','0.33');
#
#     var swiper2 = new Swiper('.swiper-container2', {
#       slidesPerView: 5,
#       spaceBetween: 12,
#       slidesPerGroup: 5,
#       loop: true,
#       loopFillGroupWithBlank: true,
#       navigation: {
#         nextEl: '.swiper-button-next',
#         prevEl: '.swiper-button-prev',
#       },
#     });
#   </script>
# <div class="view_notice">
# <p class="view_notice_date">
# <b>등록일 : 2017-12-18</b> <b>수정일 : 2017-12-20</b> </p>
# <span>저작자의 사전 동의 없이 이미지 및 문구의 무단 도용 및 복제를 금합니다.</span>
# </div>
# </div>
# {'id': 0, 'name': '완전맛있는 차돌박이찜! 미소된장마요소스도 함께~', 'thumbnail': 'https://recipe1.ezmember.co.kr/cache/recipe/2017/12/18/58dd1a9a0d0ef8ff0c60dc35965ea09d1.jpg', 'ingre': ['차돌박이', '깻잎', '팽이버섯', '숙주나물', '미소된장', '마요네즈', '올리고당', '다진마늘', '고춧가루', '청양고추', '물'], 'url': 'https://www.10000recipe.com/recipe/6881099'}

# %%
pip install selenium
# Out:
# Collecting seleniumNote: you may need to restart the kernel to use updated packages.
#
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# Requirement already satisfied: urllib3 in e:\python3.7\lib\site-packages (from selenium) (1.25.11)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
from selenium import webdriver
import time

driver = webdriver.Chrome('/learn/TIL/4th/파이썬/data_crawling/data/chromedriver')
# 웹드라이버 실행 경로 chromedriver는 폴더가 아니라 파일명입니다.
driver.get('https://www.10000recipe.com/recipe/6881099');
time.sleep(1)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

res = soup.find('div','view_step')
print(res)
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3e2463454fac> in <module>
#       4 # 웹드라이버 실행 경로 chromedriver는 폴더가 아니라 파일명입니다.
#       5 driver.get('https://www.10000recipe.com/recipe/6881099');
# ----> 6 time.sleep(1)
#       7 html = driver.page_source
#       8 soup = BeautifulSoup(html, 'html.parser')
#
# NameError: name 'time' is not defined
